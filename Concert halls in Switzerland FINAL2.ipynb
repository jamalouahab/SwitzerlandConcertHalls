# %% [markdown]
# # Concert halls in Switzerland : a territorial study
#
# ## Introduction
#
# Culture is a major factor when measuring a city's attractivity, whether it is for attracting tourists, skilled people, or simply to increase the well being
# of the inhabitants and their quality of living.
#
# There are regular discussions about cultural fundings, and here in Switzerland, the language situation (with 4 different official languages, but we will probably not have 'Romanche' speaking cities, given it is a rural population, and represents less than one % to the total population), and the federal regime, with highly independant states (called canton), makes this issue even more closely followed.
#
# One of the component of cultural activity, is the music scene, and one way to measure how lively is the musical scene in a city, is through the concert halls.
#
# The following study, aims to compare the major cities in Swizerland in terms of concert halls per capita, to provide an insight to the federal authorities, music professionals or simply to people interested in the cultural state of things from a numbers perspective, on the current distribution of the venues between the cities, opening the door for more focused studies on the budget side of things, to see how the discrepancies, if any, between the different territories could be explained, solved.
#
# By grouping the cities into distinct clusers, based on the number of venues per capita, but also the number of inhabitants, we should be able to provide the insight needed to explore further the issue.
# Through a chloropeth map, we will also be able to see how the territory part, affects the distribution.
#
# ## Data sources
#
# ### I. Data on Cities
#
# Data on cities will include:
#
# - Geospatial coordinates
# - The state in which the city is located
# - The population
# - The name of the city
#
# All this data will be scrapped from the website https://simplemaps.com/data/ch-cities as a downloadable csv.
#
#
#
# ### II. Data on concert halls
#
# Based on foursquare, we will be able to retrieve the venues, located in the different cities.
# Here is an example of concert hall as described in foursquare.
# https://foursquare.com/v/lusine/4adcdab5f964a5209a5021e3
# A concert hall, is considered a 'Category' and this data should be easy to extract using the API.
#
# We will be only focusing on the number of venues, we will need to defines the radius used to include a venue in the city or not.

# %% [markdown]
# # Data processing
#
# ## I. Get the data on cities

# %%
#Import and install all the needed libraries

# %pip install geopy
# %pip install requests
# !pip install folium

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import requests # library to handle requests
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (2020.12.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#        city      lat     lng      country iso2   admin_name  capital  \
# 0    Zürich  47.3786  8.5400  Switzerland   CH       Zürich    admin
# 1    Geneva  46.2000  6.1500  Switzerland   CH       Genève    admin
# 2     Basel  47.5606  7.5906  Switzerland   CH  Basel-Stadt    admin
# 3  Lausanne  46.5333  6.6333  Switzerland   CH         Vaud    admin
# 4      Bern  46.9480  7.4474  Switzerland   CH         Bern  primary
#
#    population  population_proper
# 0    434008.0           434008.0
# 1    201818.0           201818.0
# 2    177595.0           177595.0
# 3    138905.0           138905.0
# 4    133798.0           133798.0

# %%
#let's drop all unwanted columns : iso2 / country / capital /population

cities_data = df_data_1.drop(['iso2', 'country','capital','population'], axis=1)
cities_data.head()
# Out:
#        city      lat     lng   admin_name  population_proper
# 0    Zürich  47.3786  8.5400       Zürich           434008.0
# 1    Geneva  46.2000  6.1500       Genève           201818.0
# 2     Basel  47.5606  7.5906  Basel-Stadt           177595.0
# 3  Lausanne  46.5333  6.6333         Vaud           138905.0
# 4      Bern  46.9480  7.4474         Bern           133798.0

# %% [markdown]
# ## II. Get the foursquare data

# %% [markdown]
# ### Before gathering the foursquare data, let's first have a look of a map of Switzerland major cities

# %%
address = 'Switzerland, CH'

geolocator = Nominatim(user_agent="ch_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Switzerland are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Switzerland are 46.7985624, 8.2319736.

# %%
import folium

# create map of Toronto using latitude and longitude values
map_ch = folium.Map(location=[latitude, longitude], zoom_start=7)

# add markers to map
for lat, lng, city in zip(cities_data['lat'], cities_data['lng'],cities_data['city']):
    label = '{}'.format(city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ch)  
    
map_ch
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1727cd5ca27547cba726f7e2243a8712%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1727cd5ca27547cba726f7e2243a8712%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1727cd5ca27547cba726f7e2243a8712%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1727cd5ca27547cba726f7e2243a8712%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B46.7985624%2C%208.2319736%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails:
# CLIENT_ID: 1WPGJJATDG0S552UF1E24XIIZF43FC3UY15LLPYKQCYOYNUP
# CLIENT_SECRET:VUY2T11UDN0MIUHCSQP2BWEQ2YAHDOR5HIRXITPSJFHJFTOX

# %%
LIMIT = 200 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius


url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=1WPGJJATDG0S552UF1E24XIIZF43FC3UY15LLPYKQCYOYNUP&client_secret=VUY2T11UDN0MIUHCSQP2BWEQ2YAHDOR5HIRXITPSJFHJFTOX&v=20180604&ll=46.7985624,8.2319736&radius=5000&limit=200'

# %%
results = requests.get(url).json()
#results

print(results)
# Out:
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '600d5bc83cdc3e1394648720'}, 'response': {}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']

print(venues)

nearby_venues = json_normalize(venues) # flatten JSON

print(nearby_venues)
# Out:
# [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4c596464d3aee21e76026855', 'name': 'Melchsee-Frutt', 'location': {'lat': 46.77555299796782, 'lng': 8.268671035766602, 'labeledLatLngs': [{'label': 'display', 'lat': 46.77555299796782, 'lng': 8.268671035766602}], 'distance': 3792, 'cc': 'CH', 'city': 'Melchsee-Frutt', 'state': 'Obwalden', 'country': 'Schweiz', 'formattedAddress': ['Melchsee-Frutt', 'Schweiz']}, 'categories': [{'id': '4bf58dd8d48988d1e9941735', 'name': 'Ski Area', 'pluralName': 'Ski Areas', 'shortName': 'Ski Area', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/ski_snowboard_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4c596464d3aee21e76026855-0'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4f37d0a4e4b0a67feca01d5b', 'name': 'Frutt Lodge & Spa', 'location': {'lat': 46.77396963763963, 'lng': 8.270201922719648, 'labeledLatLngs': [{'label': 'display', 'lat': 46.77396963763963, 'lng': 8.270201922719648}], 'distance': 3998, 'postalCode': '6068', 'cc': 'CH', 'city': 'Melchsee-Frutt', 'state': 'Obwalden', 'country': 'Schweiz', 'formattedAddress': ['6068 Melchsee-Frutt', 'Schweiz']}, 'categories': [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4f37d0a4e4b0a67feca01d5b-1'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4f099a38e4b0a2229c056762', 'name': 'Bergrestaurant Käserstatt', 'location': {'lat': 46.75761081126199, 'lng': 8.218316655986012, 'labeledLatLngs': [{'label': 'display', 'lat': 46.75761081126199, 'lng': 8.218316655986012}], 'distance': 4676, 'cc': 'CH', 'city': 'Hasliberg', 'state': 'Bern', 'country': 'Schweiz', 'formattedAddress': ['Hasliberg', 'Schweiz']}, 'categories': [{'id': '4bf58dd8d48988d158941735', 'name': 'Swiss Restaurant', 'pluralName': 'Swiss Restaurants', 'shortName': 'Swiss', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/swiss_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4f099a38e4b0a2229c056762-2'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b5c35bff964a520612729e3', 'name': 'Restaurant Erzegg', 'location': {'lat': 46.768986, 'lng': 8.281331, 'labeledLatLngs': [{'label': 'display', 'lat': 46.768986, 'lng': 8.281331}], 'distance': 4999, 'cc': 'CH', 'country': 'Schweiz', 'formattedAddress': ['Schweiz']}, 'categories': [{'id': '4bf58dd8d48988d158941735', 'name': 'Swiss Restaurant', 'pluralName': 'Swiss Restaurants', 'shortName': 'Swiss', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/swiss_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}}, 'referralId': 'e-0-4b5c35bff964a520612729e3-3'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4f23f4dfe4b0acaff7aad480', 'name': 'OWI Land Road Point', 'location': {'lat': 46.82072501756771, 'lng': 8.177980560657753, 'labeledLatLngs': [{'label': 'display', 'lat': 46.82072501756771, 'lng': 8.177980560657753}], 'distance': 4796, 'postalCode': '6074', 'cc': 'CH', 'city': 'Giswil', 'state': 'Obwalden', 'country': 'Schweiz', 'formattedAddress': ['6074 Giswil', 'Schweiz']}, 'categories': [{'id': '4bf58dd8d48988d16c941735', 'name': 'Burger Joint', 'pluralName': 'Burger Joints', 'shortName': 'Burgers', 'icon': {'prefix': 'https://ss3. ...
#                          referralId  reasons.count  \
# 0    e-0-4c596464d3aee21e76026855-0              0
# 1    e-0-4f37d0a4e4b0a67feca01d5b-1              0
# 2    e-0-4f099a38e4b0a2229c056762-2              0
# 3    e-0-4b5c35bff964a520612729e3-3              0
# 4    e-0-4f23f4dfe4b0acaff7aad480-4              0
# 5    e-0-4b517179f964a520664d27e3-5              0
# 6    e-0-4ebfced76da15b4ddf0414a8-6              0
# 7    e-0-4c5ecef76147be9acfb39509-7              0
# 8    e-0-56431731498e304d7b35ef12-8              0
# 9    e-0-59161246dd70c56e0c14f2c3-9              0
# 10  e-0-4f1432b2e4b0fd29511fff97-10              0
# 11  e-0-4e2d7bc11f6ebe544267ffe2-11              0
# 12  e-0-4e6a2c7cb61cc3728d783c16-12              0
# 13  e-0-4bcf7c680ffdce72a189b2c0-13              0
#
#                                         reasons.items  \
# 0   [{'summary': 'This spot is popular', 'type': '...
# 1   [{'summary': 'This spot is popular', 'type': '...
# 2   [{'summary': 'This spot is popular', 'type': '...
# 3   [{'summary': 'This spot is popular', 'type': '...
# 4   [{'summary': 'This spot is popular', 'type': '...
# 5   [{'summary': 'This spot is popular', 'type': '...
# 6   [{'summary': 'This spot is popular', 'type': '...
# 7   [{'summary': 'This spot is popular', 'type': '...
# 8   [{'summary': 'This spot is popular', 'type': '...
# 9   [{'summary': 'This spot is popular', 'type': '...
# 10  [{'summary': 'This spot is popular', 'type': '...
# 11  [{'summary': 'This spot is popular', 'type': '...
# 12  [{'summary': 'This spot is popular', 'type': '...
# 13  [{'summary': 'This spot is popular', 'type': '...
#
#                     venue.id                            venue.name  \
# 0   4c596464d3aee21e76026855                        Melchsee-Frutt
# 1   4f37d0a4e4b0a67feca01d5b                     Frutt Lodge & Spa
# 2   4f099a38e4b0a2229c056762             Bergrestaurant Käserstatt
# 3   4b5c35bff964a520612729e3                     Restaurant Erzegg
# 4   4f23f4dfe4b0acaff7aad480                   OWI Land Road Point
# 5   4b517179f964a520664d27e3  Gondelbahn Stöckalp - Melchsee-Frutt
# 6   4ebfced76da15b4ddf0414a8                              Waldhaus
# 7   4c5ecef76147be9acfb39509                              Stöckalp
# 8   56431731498e304d7b35ef12                          Family Lodge
# 9   59161246dd70c56e0c14f2c3                     Hotel Kaiserstuhl
# 10  4f1432b2e4b0fd29511fff97                            Käserstatt
# 11  4e2d7bc11f6ebe544267ffe2                   Bahnhof Kaiserstuhl
# 12  4e6a2c7cb61cc3728d783c16                            Aelggi Alp
# 13  4bcf7c680ffdce72a189b2c0                              Landhaus
#
#     venue.location.lat  venue.location.lng  \
# 0            46.775553            8.268671
# 1            46.773970            8.270202
# 2            46.757611            8.218317
# 3            46.768986            8.281331
# 4            46.820725            8.177981
# 5            46.802460            8.278793
# 6            46.802513            8.278958
# 7            46.802363            8.279164
# 8            46.773556            8.268403
# 9            46.813394            8.175345
# 10           46.757796            8.219293
# 11           46.814370            8.175406
# 12           46.820593            8.177954
# 13           46.820888            8.177721
#
#                         venue.location.labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 46.77555299796782...
# 1   [{'label': 'display', 'lat': 46.77396963763963...
# 2   [{'label': 'display', 'lat': 46.75761081126199...
# 3   [{'label': 'display', 'lat': 46.768986, 'lng':...
# 4   [{'label': 'display', 'lat': 46.82072501756771...
# 5   [{'label': 'display', 'lat': 46.80245968832478...
# 6   [{'label': 'display', 'lat': 46.8025133991614,...
# 7   [{'label': 'display', 'lat': 46.8023625782306,...
# 8   [{'label': 'display', 'lat': 46.77355640680278...
# 9   [{'label': 'display', 'lat': 46.813394, 'lng':...
# 10  [{'label': 'display', 'lat': 46.75779565722423...
# 11  [{'label': 'display', 'lat': 46.81437033436332...
# 12  [{'label': 'display', 'lat': 46.82059286002234...
# 13  [{'label': 'display', 'lat': 46.820888, 'lng':...
#
#     venue.location.distance venue.location.cc venue.location.city  \
# 0                      3792                CH      Melchsee-Frutt
# 1                      3998                CH      Melchsee-Frutt
# 2                      4676                CH           Hasliberg
# 3                      4999                CH                 NaN
# 4                      4796                CH              Giswil
# 5                      3594                CH            Melchtal
# 6                      3607                CH                 NaN
# 7                      3620                CH                 NaN
# 8                      3931                CH                 NaN
# 9                      4619                CH                 NaN
# 10                     4639                CH                 NaN
# 11                     4655                CH         Kaiserstuhl
# 12                     4790                CH            Sachseln
# 13                     4823                CH              Giswil
#
#    venue.location.state venue.location.country  \
# 0              Obwalden                Schweiz
# 1              Obwalden                Schweiz
# 2                  Bern                Schweiz
# 3                   NaN                Schweiz
# 4              Obwalden                Schweiz
# 5              Obwalden                Schweiz
# 6                   NaN                Schweiz
# 7                   NaN                Schweiz
# 8                   NaN                Schweiz
# 9                   NaN                Schweiz
# 10                  NaN                Schweiz
# 11             Obwalden                Schweiz
# 12             Obwalden                Schweiz
# 13             Obwalden                Schweiz
#
#                       venue.location.formattedAddress  \
# 0                           [Melchsee-Frutt, Schweiz]
# 1                      [6068 Melchsee-Frutt, Schweiz]
# 2                                [Hasliberg, Schweiz]
# 3                                           [Schweiz]
# 4                              [6074 Giswil, Schweiz]
# 5   [Talstation Stöckalp (Melchtalerstrasse), Melc...
# 6                                           [Schweiz]
# 7                                           [Schweiz]
# 8                                           [Schweiz]
# 9                                           [Schweiz]
# 10                                          [Schweiz]
# 11            [Brünigstr., 6078 Kaiserstuhl, Schweiz]
# 12                                [Sachseln, Schweiz]
# 13                      [Brunigstr., Giswil, Schweiz]
#
#                                      venue.categories  venue.photos.count  \
# 0   [{'id': '4bf58dd8d48988d1e9941735', 'name': 'S...                   0
# 1   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                   0
# 2   [{'id': '4bf58dd8d48988d158941735', 'name': 'S...                   0
# 3   [{'id': '4bf58dd8d48988d158941735', 'name': 'S...                   0
# 4   [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...                   0
# 5   [{'id': '52f2ab2ebcbc57f1066b8b50', 'name': 'C...                   0
# 6   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...                   0
# 7   [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...                   0
# 8   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                   0
# 9   [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                   0
# 10  [{'id': '4bf58dd8d48988d1e9941735', 'name': 'S...                   0
# 11  [{'id': '4bf58dd8d48988d129951735', 'name': 'T...                   0
# 12  [{'id': '4bf58dd8d48988d159941735', 'name': 'T...                   0
# 13  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...                   0
#
#    venue.photos.groups venue.location.postalCode venue.location.address  \
# 0                   []                       NaN                    NaN
# 1                   []                      6068                    NaN
# 2                   []                       NaN                    NaN
# 3                   []                       NaN                    NaN
# 4                   []                      6074                    NaN
# 5                   []                       NaN    Talstation Stöckalp
# 6                   []                       NaN                    NaN
# 7                   []                       NaN                    NaN
# 8                   []                       NaN                    NaN
# 9                   []                       NaN                    NaN
# 10                  []                       NaN                    NaN
# 11                  []                      6078             Brünigstr.
# 12                  []                       NaN                    NaN
# 13                  []                       NaN             Brunigstr.
#
#    venue.location.crossStreet
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5           Melchtalerstrasse
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
LIMIT = 200

# %%
def getNearbyVenues(names, latitudes, longitudes):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['city', 
                  'lat', 
                  'lng', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
ch_venues = getNearbyVenues(names=cities_data['city'],
                                latitudes=cities_data['lat'],
                                longitudes=cities_data['lng']
                                )
# Out:
# Zürich
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-1861b0c5ff4e> in <module>
#       1 ch_venues2 = getNearbyVenues(names=cities_data['city'],
#       2                                 latitudes=cities_data['lat'],
# ----> 3                                 longitudes=cities_data['lng']
#       4                                 )
#
# <ipython-input-188-46cae91eb596> in getNearbyVenues(names, latitudes, longitudes)
#      16
#      17         # make the GET request
# ---> 18         results = requests.get(url).json()["response"]['groups'][0]['items']
#      19
#      20         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %%
print(ch_venues.shape)
# Out:
# (6057, 7)

# %%
ch_test = ch_venues.groupby('Venue Category').count()
ch_test_distinct = ch_venues['Venue Category'].unique()
print(ch_test_distinct)
# Out:
# ['Chocolate Shop' 'Plaza' 'Gourmet Shop' 'Bar'
#  'Vegetarian / Vegan Restaurant' 'Sporting Goods Shop' 'Pedestrian Plaza'
#  'Cocktail Bar' 'Sandwich Place' 'Hotel Bar' 'Watch Shop' 'Hotel' 'Café'
#  'Falafel Restaurant' 'Cupcake Shop' 'Liquor Store' 'Asian Restaurant'
#  'Bakery' 'Train Station' 'Snack Place' 'Department Store' 'Shoe Store'
#  'Movie Theater' 'Gym / Fitness Center' 'Swiss Restaurant' 'Dessert Shop'
#  'Furniture / Home Store' 'Cultural Center' 'Juice Bar' 'Gastropub'
#  'Japanese Restaurant' 'Art Museum' 'Coffee Shop' 'Bookstore'
#  'Burger Joint' 'Cuban Restaurant' 'Italian Restaurant' 'Sushi Restaurant'
#  'Pool' 'Electronics Store' 'Supermarket' 'Science Museum' 'Diner'
#  'Thai Restaurant' 'Flea Market' 'Spanish Restaurant' 'French Restaurant'
#  'Waterfront' 'Arts & Crafts Store' 'Trade School' 'Park' 'Wine Bar'
#  'Mountain' 'Ice Cream Shop' 'Opera House' 'Bratwurst Joint'
#  'Neighborhood' 'Steakhouse' 'Boutique' 'Jewelry Store' 'Art Gallery'
#  'Fountain' 'History Museum' 'Peruvian Restaurant' 'Concert Hall'
#  'Coworking Space' 'Farmers Market' 'Music Venue' 'Beach' 'Tea Room'
#  'Accessories Store' 'Chinese Restaurant' 'Vietnamese Restaurant'
#  'Dim Sum Restaurant' 'Bistro' 'Salon / Barbershop' 'Restaurant' 'Museum'
#  'Noodle House' 'Scenic Lookout' 'Botanical Garden' 'Jazz Club'
#  'Historic Site' 'Beer Garden' 'Gym' 'Shopping Mall' 'Salad Place'
#  'Food Court' 'Zoo' 'Bathing Area' 'Brewery' 'Pizza Place' 'Tram Station'
#  'Lounge' 'Soccer Stadium' 'Clothing Store' 'Turkish Restaurant' 'Farm'
#  'Forest' 'Modern European Restaurant' 'Canal Lock' 'Grocery Store'
#  'German Restaurant' 'Greek Restaurant' 'Golf Course' 'Convention Center'
#  'Bus Stop' 'Fast Food Restaurant' 'Jewish Restaurant' 'Church'
#  'Athletics & Sports' 'Nightclub' 'Mediterranean Restaurant' 'Airport'
#  'Arcade' 'Bubble Tea Shop' 'Beach Bar' 'Harbor / Marina'
#  'Outdoors & Recreation' 'Theater' 'Campground' 'Bed & Breakfast'
#  'Paper / Office Supplies Store' 'Tennis Court' 'Monument / Landmark'
#  'Tapas Restaurant' 'Performing Arts Venue' 'Garden' 'Creperie'
#  'Bagel Shop' 'Food & Drink Shop' 'Water Park' 'Hockey Arena'
#  'Indian Restaurant' 'Comedy Club' 'Irish Pub' 'Public Art'
#  'Organic Grocery' 'Hostel' 'Burrito Place' 'Multiplex'
#  'Mexican Restaurant' 'Australian Restaurant' 'Insurance Office'
#  'Hardware Store' 'American Restaurant' 'Convenience Store'
#  'Bowling Alley' 'Bridge' 'Moroccan Restaurant' 'Wine Shop' 'Food' 'Lake'
#  'Butcher' 'Hookah Bar' 'Library' 'Field' 'Skating Rink' 'Pub'
#  'Yoga Studio' 'Seafood Restaurant' 'BBQ Joint' 'Motel'
#  'Middle Eastern Restaurant' 'Stadium' 'Martial Arts School' 'Castle'
#  'Soccer Field' 'Casino' 'Discount Store' 'Light Rail Station'
#  'Gas Station' 'Platform' 'Rock Club' 'Candy Store' 'Trattoria/Osteria'
#  'Non-Profit' 'Resort' 'Event Space' 'Sports Club' 'Photography Studio'
#  'Waterfall' 'Palace' 'Miscellaneous Shop' 'Spa' 'General Entertainment'
#  'Fondue Restaurant' 'Ski Area' 'Wings Joint' 'Trail' 'Ski Chairlift'
#  'Beer Bar' 'Breakfast Spot' 'Argentinian Restaurant' 'Rock Climbing Spot'
#  'Pharmacy' 'Auto Workshop' 'Motorcycle Shop'
#  'Eastern European Restaurant' 'Sports Bar' 'Pet Store' 'Tennis Stadium'
#  'Hot Spring' 'Arts & Entertainment' 'Hobby Shop' 'Playground'
#  'Zoo Exhibit' 'Garden Center' 'Bus Station' 'Pier' 'Sculpture Garden'
#  'Hawaiian Restaurant' 'Scandinavian Restaurant' 'Market'
#  'Outdoor Sculpture' 'Rest Area' 'Donut Shop' 'Toy / Game Store'
#  'Shop & Service' 'Kebab Restaurant' 'Theme Park' 'Mobile Phone Shop'
#  'Border Crossing' 'River' 'Squash Court' 'Cheese Shop'
#  'Other Great Outdoors' 'Flower Shop' 'Winery' 'Factory' 'Soup Place'
#  'Taverna' 'Parking' 'Kids Store' 'Drugstore' 'Deli / Bodega' 'Bank'
#  'Doner Restaurant' 'Smoke Shop' 'Automotive Shop' 'Auto Dealership'
#  'Indie Movie Theater' 'Climbing Gym' 'Big Box Store' 'Business Service'
#  'Beer Store' 'Airport Lounge' 'Lingerie Store' 'Indonesian Restaurant'
#  'Whisky Bar' 'Circus' 'Theme Restaurant' 'Austrian Restaurant'
#  'Airport Service' 'Rental Car Location' 'General College & University'
#  'Recreation Center' 'Island' 'Community Center' 'Road' 'Dance Studio'
#  'Korean Restaurant' 'Auto Garage' 'Speakeasy' 'Vineyard' 'Racetrack'
#  'Brazilian Restaurant' 'Gym Pool' 'Intersection' 'Pool Hall' 'Ski Chalet'
#  'Track Stadium' 'Airport Food Court' 'Indie Theater'
#  'Construction & Landscaping' 'General Travel' 'National Park'
#  'Fish & Chips Shop' 'Food Truck' 'Lighting Store' 'Boat or Ferry'
#  'Tech Startup' 'Apres Ski Bar' 'Piano Bar' 'Buffet' 'Ski Trail'
#  'Ski Lodge' 'Indoor Play Area' 'Tunnel' 'Churrascaria' 'Cable Car' 'Town'
#  'Lebanese Restaurant' 'ATM' 'Health & Beauty Service' 'Music Store'
#  'Go Kart Track' 'Outlet Mall' 'Comfort Food Restaurant'
#  'Other Repair Shop' 'Home Service' 'Mac & Cheese Joint' 'Port']

# %% [markdown]
# ### We can see unfortunately, that our first asumption, that the concert halls could be retrieved using the category 'Concert Hall' is false, we will need to add more categories, as the data inputed by the users includes different categories (for example 'Nightclub'), this extension will probably lead to some false positives, we will see how we can handle those later.

# %%
ch_concert_test = ch_venues[ch_venues['Venue Category'].isin(['Concert Hall','Music Venue','Opera House','Performing Arts Venue','Nightclub'])].reset_index(drop=True)
#ch_concert_halls

# %%
ch_concert_test.head()
print(ch_concert_test.shape)
# Out:
# (74, 7)

# %%
ch_concert_test.head(75)
# Out:
#         city      lat     lng                               Venue  \
# 0     Zürich  47.3786  8.5400                           Opernhaus
# 1     Geneva  46.2000  6.1500                       Victoria Hall
# 2     Geneva  46.2000  6.1500               Les Enfants Terribles
# 3   Lausanne  46.5333  6.6333                           Les Docks
# 4       Bern  46.9480  7.4474             Rendez-vous Bundesplatz
# ..       ...      ...     ...                                 ...
# 69    Hinwil  47.3033  8.8444                       Rock the Ring
# 70    Hinwil  47.3033  8.8444                            Kamäleon
# 71     Davos  46.8091  9.8398  Hotel Grischa - Pulsa Bar & Lounge
# 72   Aarberg  47.0438  7.2736                           KuFa Lyss
# 73    Haslen  47.3693  9.3675                     Kulturhaus Rose
#
#     Venue Latitude  Venue Longitude         Venue Category
# 0        47.365212         8.546604            Opera House
# 1        46.201467         6.141059           Concert Hall
# 2        46.193950         6.145032            Music Venue
# 3        46.522425         6.619011              Nightclub
# 4        46.947162         7.444121  Performing Arts Venue
# ..             ...              ...                    ...
# 69       47.289021         8.817097           Concert Hall
# 70       47.268352         8.871696              Nightclub
# 71       46.791510         9.820268              Nightclub
# 72       47.080595         7.294434            Music Venue
# 73       47.379888         9.345759            Music Venue
#
# [74 rows x 7 columns]

# %% [markdown]
# ### By looking at the data, we can see that we have several issues:
#
# i. Duplicates, related to the 'radius' parameter used in our foursquare calls
# ii. Inclusions in the 'city' columns, of neighborhoods, rather than cities, specially for the main cities (Zurich, Geneva and Bern)
#
# Given that the result set is small, we will try to clean it up manually before going further

# %%
#first let's remove the duplicates
ch_cleaned1 = ch_concert_test.drop_duplicates(subset=['Venue'], keep='last').reset_index(drop=True)
ch_cleaned1.head(100)
print(ch_cleaned1.shape)

ch_cleaned1.head(50)
# Out:
# (49, 7)
#                  city      lat     lng                               Venue  \
# 0              Zürich  47.3786  8.5400                           Opernhaus
# 1          Winterthur  47.4992  8.7267                   Albani Music Club
# 2          Winterthur  47.4992  8.7267                            Salzhaus
# 3        Sankt Gallen  47.4233  9.3772                          Rock Story
# 4        Sankt Gallen  47.4233  9.3772                              Palace
# 5        Sankt Gallen  47.4233  9.3772                           Lokremise
# 6              Lugano  46.0103  8.9625                  Living Room Lugano
# 7         Biel/Bienne  47.1372  7.2472                 Gaskessel | Coupole
# 8                Thun  46.7590  7.6300                              KKThun
# 9           Neuchâtel  46.9903  6.9306                        Case à Chocs
# 10  Yverdon-les-Bains  46.7785  6.6408                       Amalgame Club
# 11  Yverdon-les-Bains  46.7785  6.6408                    Café du Commerce
# 12              Emmen  47.0772  8.3000                        Gewerbehalle
# 13              Emmen  47.0772  8.3000                  The Bruch Brothers
# 14             Kriens  47.0344  8.2800                    Pavillon Am Quai
# 15           Montreux  46.4333  6.9167                   Montreux Jazz Lab
# 16           Montreux  46.4333  6.9167               Auditorium Stravinski
# 17         Frauenfeld  47.5558  8.8964                           Eisenwerk
# 18              Bulle  46.6167  7.0500                             globull
# 19        Kreuzlingen  47.6458  9.1783                             Kantine
# 20        Kreuzlingen  47.6458  9.1783                         Kulturladen
# 21             Riehen  47.5794  7.6512                       Kaserne Basel
# 22             Riehen  47.5794  7.6512                             Burghof
# 23              Aarau  47.3923  8.0446                                KiFF
# 24               Nyon  46.3820  6.2389                         Usine à Gaz
# 25               Nyon  46.3820  6.2389                   Caribana Festival
# 26               Nyon  46.3820  6.2389                Paléo - Grande Scène
# 27              Vevey  46.4667  6.8500                       Rocking-Chair
# 28             Kloten  47.4481  8.5828                      Zürich Openair
# 29              Baden  47.4729  8.3080                          Nordportal
# 30               Onex  46.1833  6.1000               Les Enfants Terribles
# 31               Onex  46.1833  6.1000                        Le Chat Noir
# 32               Onex  46.1833  6.1000                       Victoria Hall
# 33               Onex  46.1833  6.1000        Bâtiment des Forces Motrices
# 34               Onex  46.1833  6.1000                             L'Usine
# 35           Adliswil  47.3122  8.5256                         Rote Fabrik
# 36              Pully  46.5167  6.6667                           Les Docks
# 37         Regensdorf  47.4383  8.4744                        Dilaila Club
# 38            Muttenz  47.5228  7.6452                     St. Jakobshalle
# 39            Muttenz  47.5228  7.6452                           Hinterhof
# 40      Ostermundigen  46.9553  7.4833             Rendez-vous Bundesplatz
# 41              Olten  47.3531  7.9078                            Terminus
# 42          Solothurn  47.2081  7.5375                Kulturfabrik Kofmehl
# 43           Pratteln  47.5185  7.6928                    Z7 Konzertfabrik
# 44             Hinwil  47.3033  8.8444                       Rock the Ring
# 45             Hinwil  47.3033  8.8444                            Kamäleon
# 46              Davos  46.8091  9.8398  Hotel Grischa - Pulsa Bar & Lounge
# 47            Aarberg  47.0438  7.2736                           KuFa Lyss
# 48             Haslen  47.3693  9.3675                     Kulturhaus Rose
#
#     Venue Latitude  Venue Longitude         Venue Category
# 0        47.365212         8.546604            Opera House
# 1        47.498395         8.729155              Nightclub
# 2        47.497550         8.722566              Nightclub
# 3        47.427014         9.374442            Music Venue
# 4        47.426564         9.373650            Music Venue
# 5        47.421551         9.365820  Performing Arts Venue
# 6        46.020717         8.958074              Nightclub
# 7        47.135980         7.250273           Concert Hall
# 8        46.742852         7.629493           Concert Hall
# 9        46.989271         6.921655            Music Venue
# 10       46.782260         6.649767            Music Venue
# 11       46.809283         6.645757           Concert Hall
# 12       47.053397         8.294718              Nightclub
# 13       47.051820         8.299703            Music Venue
# 14       47.054421         8.313194            Music Venue
# 15       46.438773         6.905324            Music Venue
# 16       46.439217         6.904735           Concert Hall
# 17       47.561069         8.893449           Concert Hall
# 18       46.626393         7.067191              Nightclub
# 19       47.673870         9.159359            Music Venue
# 20       47.678899         9.163446            Music Venue
# 21       47.563368         7.590992  Performing Arts Venue
# 22       47.610921         7.659369           Concert Hall
# 23       47.398780         8.063911           Concert Hall
# 24       46.383878         6.244024            Music Venue
# 25       46.359993         6.217858           Concert Hall
# 26       46.402713         6.206416            Music Venue
# 27       46.470498         6.851242            Music Venue
# 28       47.439275         8.553731            Music Venue
# 29       47.481231         8.300219           Concert Hall
# 30       46.193950         6.145032            Music Venue
# 31       46.185081         6.142201            Music Venue
# 32       46.201467         6.141059           Concert Hall
# 33       46.204630         6.136797           Concert Hall
# 34       46.204118         6.136164           Concert Hall
# 35       47.343607         8.536923            Music Venue
# 36       46.522425         6.619011              Nightclub
# 37       47.441772         8.460931              Nightclub
# 38       47.540208         7.618173           Concert Hall
# 39       47.539853         7.606743              Nightclub
# 40       46.947162         7.444121  Performing Arts Venue
# 41       47.352085         7.903778              Nightclub
# 42       47.200730         7.528310           Concert Hall
# 43       47.527321         7.694165           Concert Hall
# 44       47.289021         8.817097           Concert Hall
# 45       47.268352         8.871696              Nightclub
# 46       46.791510         9.820268              Nightclub
# 47       47.080595         7.294434            Music Venue
# 48       47.379888         9.345759            Music Venue

# %% [markdown]
# ### Let's clean out the data, in order to avoid cities belonging to a bigger aglomeration in our table, once again we will be using data from
# https://simplemaps.com/data/ch-cities
#
# ####  'Geneva'
#
# 'Onex'
#
#
# #### 'Lausanne'
#
# Pully
#
# #### 'Bern'
#
# Ostermundigen
#
# #### 'Basel'
# 'Riehen'
# Muttenz
# Pratteln
#
# #### Zurich
#
# 'Kloten'
# 'Adliswil'
# Regensdorf

# %%
ch_cleaned = ch_cleaned1.replace('Onex','Geneva').reset_index(drop=True)

ch_cleaned.head(50)
# Out:
#                  city      lat     lng                               Venue  \
# 0              Zürich  47.3786  8.5400                           Opernhaus
# 1          Winterthur  47.4992  8.7267                   Albani Music Club
# 2          Winterthur  47.4992  8.7267                            Salzhaus
# 3        Sankt Gallen  47.4233  9.3772                          Rock Story
# 4        Sankt Gallen  47.4233  9.3772                              Palace
# 5        Sankt Gallen  47.4233  9.3772                           Lokremise
# 6              Lugano  46.0103  8.9625                  Living Room Lugano
# 7         Biel/Bienne  47.1372  7.2472                 Gaskessel | Coupole
# 8                Thun  46.7590  7.6300                              KKThun
# 9           Neuchâtel  46.9903  6.9306                        Case à Chocs
# 10  Yverdon-les-Bains  46.7785  6.6408                       Amalgame Club
# 11  Yverdon-les-Bains  46.7785  6.6408                    Café du Commerce
# 12              Emmen  47.0772  8.3000                        Gewerbehalle
# 13              Emmen  47.0772  8.3000                  The Bruch Brothers
# 14             Kriens  47.0344  8.2800                    Pavillon Am Quai
# 15           Montreux  46.4333  6.9167                   Montreux Jazz Lab
# 16           Montreux  46.4333  6.9167               Auditorium Stravinski
# 17         Frauenfeld  47.5558  8.8964                           Eisenwerk
# 18              Bulle  46.6167  7.0500                             globull
# 19        Kreuzlingen  47.6458  9.1783                             Kantine
# 20        Kreuzlingen  47.6458  9.1783                         Kulturladen
# 21             Riehen  47.5794  7.6512                       Kaserne Basel
# 22             Riehen  47.5794  7.6512                             Burghof
# 23              Aarau  47.3923  8.0446                                KiFF
# 24               Nyon  46.3820  6.2389                         Usine à Gaz
# 25               Nyon  46.3820  6.2389                   Caribana Festival
# 26               Nyon  46.3820  6.2389                Paléo - Grande Scène
# 27              Vevey  46.4667  6.8500                       Rocking-Chair
# 28             Kloten  47.4481  8.5828                      Zürich Openair
# 29              Baden  47.4729  8.3080                          Nordportal
# 30             Geneva  46.1833  6.1000               Les Enfants Terribles
# 31             Geneva  46.1833  6.1000                        Le Chat Noir
# 32             Geneva  46.1833  6.1000                       Victoria Hall
# 33             Geneva  46.1833  6.1000        Bâtiment des Forces Motrices
# 34             Geneva  46.1833  6.1000                             L'Usine
# 35           Adliswil  47.3122  8.5256                         Rote Fabrik
# 36              Pully  46.5167  6.6667                           Les Docks
# 37         Regensdorf  47.4383  8.4744                        Dilaila Club
# 38            Muttenz  47.5228  7.6452                     St. Jakobshalle
# 39            Muttenz  47.5228  7.6452                           Hinterhof
# 40      Ostermundigen  46.9553  7.4833             Rendez-vous Bundesplatz
# 41              Olten  47.3531  7.9078                            Terminus
# 42          Solothurn  47.2081  7.5375                Kulturfabrik Kofmehl
# 43           Pratteln  47.5185  7.6928                    Z7 Konzertfabrik
# 44             Hinwil  47.3033  8.8444                       Rock the Ring
# 45             Hinwil  47.3033  8.8444                            Kamäleon
# 46              Davos  46.8091  9.8398  Hotel Grischa - Pulsa Bar & Lounge
# 47            Aarberg  47.0438  7.2736                           KuFa Lyss
# 48             Haslen  47.3693  9.3675                     Kulturhaus Rose
#
#     Venue Latitude  Venue Longitude         Venue Category
# 0        47.365212         8.546604            Opera House
# 1        47.498395         8.729155              Nightclub
# 2        47.497550         8.722566              Nightclub
# 3        47.427014         9.374442            Music Venue
# 4        47.426564         9.373650            Music Venue
# 5        47.421551         9.365820  Performing Arts Venue
# 6        46.020717         8.958074              Nightclub
# 7        47.135980         7.250273           Concert Hall
# 8        46.742852         7.629493           Concert Hall
# 9        46.989271         6.921655            Music Venue
# 10       46.782260         6.649767            Music Venue
# 11       46.809283         6.645757           Concert Hall
# 12       47.053397         8.294718              Nightclub
# 13       47.051820         8.299703            Music Venue
# 14       47.054421         8.313194            Music Venue
# 15       46.438773         6.905324            Music Venue
# 16       46.439217         6.904735           Concert Hall
# 17       47.561069         8.893449           Concert Hall
# 18       46.626393         7.067191              Nightclub
# 19       47.673870         9.159359            Music Venue
# 20       47.678899         9.163446            Music Venue
# 21       47.563368         7.590992  Performing Arts Venue
# 22       47.610921         7.659369           Concert Hall
# 23       47.398780         8.063911           Concert Hall
# 24       46.383878         6.244024            Music Venue
# 25       46.359993         6.217858           Concert Hall
# 26       46.402713         6.206416            Music Venue
# 27       46.470498         6.851242            Music Venue
# 28       47.439275         8.553731            Music Venue
# 29       47.481231         8.300219           Concert Hall
# 30       46.193950         6.145032            Music Venue
# 31       46.185081         6.142201            Music Venue
# 32       46.201467         6.141059           Concert Hall
# 33       46.204630         6.136797           Concert Hall
# 34       46.204118         6.136164           Concert Hall
# 35       47.343607         8.536923            Music Venue
# 36       46.522425         6.619011              Nightclub
# 37       47.441772         8.460931              Nightclub
# 38       47.540208         7.618173           Concert Hall
# 39       47.539853         7.606743              Nightclub
# 40       46.947162         7.444121  Performing Arts Venue
# 41       47.352085         7.903778              Nightclub
# 42       47.200730         7.528310           Concert Hall
# 43       47.527321         7.694165           Concert Hall
# 44       47.289021         8.817097           Concert Hall
# 45       47.268352         8.871696              Nightclub
# 46       46.791510         9.820268              Nightclub
# 47       47.080595         7.294434            Music Venue
# 48       47.379888         9.345759            Music Venue

# %% [markdown]
# ## Now let's examine the results for Geneva, just to assess how reliable is the data, we have various way of doing so, but we will compare the foursqure results with data from a cultural agenda.
# https://www.leprogramme.ch/concerts/Geneve

# %%
ch_geneva = ch_concert_test[ch_concert_test['city'] == 'Geneva']


ch_test2 = ch_zurich.groupby('Venue Category').count()
ch_test2_distinct = ch_zurich['Venue Category'].unique()
print(ch_test2_distinct)
ch_geneva.head(100)
# Out:
# ['Neighborhood' 'Plaza' 'Dessert Shop' 'Steakhouse' 'Park' 'Boutique'
#  'Jewelry Store' 'Swiss Restaurant' 'Art Museum' 'Hotel' 'Art Gallery'
#  'Ice Cream Shop' 'Bookstore' 'Waterfront' 'French Restaurant'
#  'Movie Theater' 'Department Store' 'Italian Restaurant' 'Fountain'
#  'History Museum' 'Peruvian Restaurant' 'Concert Hall' 'Café'
#  'Coworking Space' 'Farmers Market' 'Coffee Shop' 'Music Venue'
#  'Burger Joint' 'Cocktail Bar' 'Japanese Restaurant' 'Beach'
#  'Chocolate Shop' 'Bar' 'Tea Room' 'Accessories Store'
#  'Falafel Restaurant' 'Chinese Restaurant' 'Vietnamese Restaurant'
#  'Electronics Store' 'Dim Sum Restaurant' 'Thai Restaurant' 'Supermarket'
#  'Bistro' 'Salon / Barbershop' 'Restaurant' 'Museum' 'Noodle House']
#      city   lat   lng                  Venue  Venue Latitude  Venue Longitude  \
# 1  Geneva  46.2  6.15          Victoria Hall       46.201467         6.141059
# 2  Geneva  46.2  6.15  Les Enfants Terribles       46.193950         6.145032
#
#   Venue Category
# 1   Concert Hall
# 2    Music Venue

# %% [markdown]
# ## Foursqure limits
#
# Duplicates
# Cannot be sure that is complete
# let's compare with another source for Geneva concerts place
# Festivals
# limits linked with the subscription type
